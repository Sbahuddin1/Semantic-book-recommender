# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv('/books_cleaned.csv')

# %%
books["categories"].value_counts().reset_index()
# Out:
#                            categories  count
# 0                             Fiction   2232
# 1                    Juvenile Fiction    443
# 2           Biography & Autobiography    343
# 3                             History    223
# 4                  Literary Criticism    135
# ..                                ...    ...
# 491                        Air pilots      1
# 492                 Authors, Canadian      1
# 493  Literary Criticism & Collections      1
# 494               Art museum curators      1
# 495                         Catholics      1
#
# [496 rows x 2 columns]

# %%
books["categories"].value_counts().reset_index().query("count > 50")
# Out:
#                    categories  count
# 0                     Fiction   2232
# 1            Juvenile Fiction    443
# 2   Biography & Autobiography    343
# 3                     History    223
# 4          Literary Criticism    135
# 5     Comics & Graphic Novels    125
# 6                    Religion    125
# 7                  Philosophy    125
# 8                       Drama     98
# 9         Juvenile Nonfiction     81
# 10                    Science     61
# 11                     Poetry     57
# 12       Business & Economics     55
# 13       Literary Collections     53

# %%
books[books["categories"] == "Juvenile Fiction"]
# Out:
#              isbn13      isbn10  \
# 30    9780006646006  000664600X
# 83    9780020442608  0020442602
# 89    9780030547744  0030547741
# 90    9780060000141  0060000147
# 91    9780060001537  0060001534
# ...             ...         ...
# 5292  9781595140326  1595140328
# 5312  9781596792500  1596792507
# 5326  9781599900056  159990005X
# 5395  9781844580514  1844580512
# 5550  9781932416374  1932416374
#
#                                                   title  \
# 30                                   Ocean Star Express
# 83                       The voyage of the Dawn Treader
# 89                             Where the Red Fern Grows
# 90                                       Poppy's Return
# 91                                    Diary of a Spider
# ...                                                 ...
# 5292                                       So Yesterday
# 5312  Sherlock Holmes and the Case of the Hound of t...
# 5326                                    The Drift House
# 5395                               Attack of the Jaguar
# 5550                The Very Persistent Gappers of Frip
#
#                                   authors        categories  \
# 30               Mark Haddon;Peter Sutton  Juvenile Fiction
# 83                    Clive Staples Lewis  Juvenile Fiction
# 89                           Wilson Rawls  Juvenile Fiction
# 90                                    Avi  Juvenile Fiction
# 91                          Doreen Cronin  Juvenile Fiction
# ...                                   ...               ...
# 5292                     Scott Westerfeld  Juvenile Fiction
# 5312  Arthur Conan Doyle;Malvina G. Vogel  Juvenile Fiction
# 5326                            Dale Peck  Juvenile Fiction
# 5395                         M. A. Harvey  Juvenile Fiction
# 5550           George Saunders;Lane Smith  Juvenile Fiction
#
#                                               thumbnail  \
# 30    http://books.google.com/books/content?id=I2QZA...
# 83    http://books.google.com/books/content?id=fDD3C...
# 89    http://books.google.com/books/content?id=IHpRw...
# 90    http://books.google.com/books/content?id=XbcMJ...
# 91    http://books.google.com/books/content?id=UWvZo...
# ...                                                 ...
# 5292  http://books.google.com/books/content?id=oRZy5...
# 5312  http://books.google.com/books/content?id=EWgWP...
# 5326  http://books.google.com/books/content?id=kbwPY...
# 5395  http://books.google.com/books/content?id=3HUdt...
# 5550  http://books.google.com/books/content?id=xYJOP...
#
#                                             description  published_year  \
# 30    Joe and his parents are enjoying a summer holi...          2002.0
# 83    The "Dawn Treader" is the first ship Narnia ha...          1970.0
# 89    A young boy living in the Ozarks achieves his ...          2000.0
# 90    There's trouble at Gray House, the girlhood ho...          2006.0
# 91    This is the diary ... of a spider. But don't b...          2005.0
# ...                                                 ...             ...
# 5292  Trend-spotter and fashion expert Hunter Braque...          2005.0
# 5312  Sherlock Holmes and Dr. Watson travel to the b...          2005.0
# 5326  Sent to stay with their uncle in a ship-like h...          2006.0
# 5395  This training manual for operatives of Xtreme ...          2004.0
# 5550  A novel set in the seaside village of Frip fol...          2006.0
#
#       average_rating  num_pages  ratings_count  \
# 30              3.50       32.0            1.0
# 83              4.09      216.0         2869.0
# 89              4.37      288.0           95.0
# 90              3.99      256.0         1086.0
# 91              4.25       40.0         7903.0
# ...              ...        ...            ...
# 5292            3.58      256.0        10282.0
# 5312            4.51      237.0           28.0
# 5326            3.64      437.0          595.0
# 5395            3.40      125.0            4.0
# 5550            4.11       84.0         2317.0
#
#                                      title_and_subtitle  \
# 30                                   Ocean Star Express
# 83                       The voyage of the Dawn Treader
# 89    Where the Red Fern Grows : The Story of Two Do...
# 90                                       Poppy's Return
# 91                                    Diary of a Spider
# ...                                                 ...
# 5292                             So Yesterday : A Novel
# 5312  Sherlock Holmes and the Case of the Hound of t...
# 5326                 The Drift House : The First Voyage
# 5395                               Attack of the Jaguar
# 5550                The Very Persistent Gappers of Frip
#
#                                      tagged_description
# 30    9780006646006 Joe and his parents are enjoying...
# 83    9780020442608 The "Dawn Treader" is the first ...
# 89    9780030547744 A young boy living in the Ozarks...
# 90    9780060000141 There's trouble at Gray House, t...
# 91    9780060001537 This is the diary ... of a spide...
# ...                                                 ...
# 5292  9781595140326 Trend-spotter and fashion expert...
# 5312  9781596792500 Sherlock Holmes and Dr. Watson t...
# 5326  9781599900056 Sent to stay with their uncle in...
# 5395  9781844580514 This training manual for operati...
# 5550  9781932416374 A novel set in the seaside villa...
#
# [443 rows x 13 columns]

# %%
books[books["categories"] == "Juvenile Nonfiction"]
# Out:
#              isbn13      isbn10                          title  \
# 111   9780060277406  0060277408     The Secret Garden Cookbook
# 112   9780060278427  0060278420                  Laura's Album
# 232   9780060782139  0060782137    Time For Kids: Butterflies!
# 271   9780060882600  0060882603  The Annotated Charlotte's Web
# 449   9780064462044  0064462048    My Little House Crafts Book
# ...             ...         ...                            ...
# 5115  9781580495868  1580495869       The Red Badge of Courage
# 5183  9781586853334  1586853333      The Big Book of Boy Stuff
# 5428  9781857232097  1857232097            The Fires of Heaven
# 5532  9781931414166  1931414165            The Brooklyn Bridge
# 5580  9783791329284  3791329286                 Joseph Cornell
#
#                                authors           categories  \
# 111                         Amy Cotler  Juvenile Nonfiction
# 112                   William Anderson  Juvenile Nonfiction
# 232           Editors of TIME For Kids  Juvenile Nonfiction
# 271                        E. B. White  Juvenile Nonfiction
# 449              Carolyn Strom Collins  Juvenile Nonfiction
# ...                                ...                  ...
# 5115                     Stephen Crane  Juvenile Nonfiction
# 5183                         Bart King  Juvenile Nonfiction
# 5428                     Robert Jordan  Juvenile Nonfiction
# 5532    Elizabeth Mann;Alan Witschonke  Juvenile Nonfiction
# 5580  Joseph Cornell;Alison Baverstock  Juvenile Nonfiction
#
#                                               thumbnail  \
# 111   http://books.google.com/books/content?id=c7E_H...
# 112   http://books.google.com/books/content?id=_zTkq...
# 232   http://books.google.com/books/content?id=OdZxn...
# 271   http://books.google.com/books/content?id=vaYYH...
# 449   http://books.google.com/books/content?id=lTzrs...
# ...                                                 ...
# 5115  http://books.google.com/books/content?id=lN1ga...
# 5183  http://books.google.com/books/content?id=08Ilm...
# 5428  http://books.google.com/books/content?id=4HyfQ...
# 5532  http://books.google.com/books/content?id=s28MA...
# 5580  http://books.google.com/books/content?id=KnO8A...
#
#                                             description  published_year  \
# 111   Frances Hodgson Burnett's The Secret Garden de...          1999.0
# 112   Though best known as the author of the Little ...          1998.0
# 232   Butterflies There are 20,000 different kinds o...          2006.0
# 271   Charlotte's Web, one of America's best-loved c...          2006.0
# 449   Make the same pioneer crafts that Laura did! I...          1998.0
# ...                                                 ...             ...
# 5115  As he faces battle in the Civil War for the fi...          2004.0
# 5183  There's this boy. Let's say he's somewhere bet...          2004.0
# 5428  The fifth book in Robert Jordan's internationa...          1994.0
# 5532  Describes the construction of the Brooklyn Bri...          2006.0
# 5580  Provides an introduction to the American artis...          2003.0
#
#       average_rating  num_pages  ratings_count  \
# 111             4.28      128.0          142.0
# 112             4.30       80.0          713.0
# 232             4.00       32.0           20.0
# 271             4.16      320.0           41.0
# 449             4.05       64.0           56.0
# ...              ...        ...            ...
# 5115            3.23      170.0        74477.0
# 5183            4.24      292.0          141.0
# 5428            4.15      912.0       106302.0
# 5532            4.44       46.0           35.0
# 5580            4.06       27.0           31.0
#
#                                      title_and_subtitle  \
# 111   The Secret Garden Cookbook : Recipes Inspired ...
# 112   Laura's Album : A Remembrance Scrapbook of Lau...
# 232                         Time For Kids: Butterflies!
# 271                       The Annotated Charlotte's Web
# 449   My Little House Crafts Book : 18 Projects from...
# ...                                                 ...
# 5115                           The Red Badge of Courage
# 5183                          The Big Book of Boy Stuff
# 5428                                The Fires of Heaven
# 5532                                The Brooklyn Bridge
# 5580                  Joseph Cornell : Secrets in a Box
#
#                                      tagged_description
# 111   9780060277406 Frances Hodgson Burnett's The Se...
# 112   9780060278427 Though best known as the author ...
# 232   9780060782139 Butterflies There are 20,000 dif...
# 271   9780060882600 Charlotte's Web, one of America'...
# 449   9780064462044 Make the same pioneer crafts tha...
# ...                                                 ...
# 5115  9781580495868 As he faces battle in the Civil ...
# 5183  9781586853334 There's this boy. Let's say he's...
# 5428  9781857232097 The fifth book in Robert Jordan'...
# 5532  9781931414166 Describes the construction of th...
# 5580  9783791329284 Provides an introduction to the ...
#
# [81 rows x 13 columns]

# %%
category_mapping = {'Fiction' : "Fiction",
 'Juvenile Fiction': "Children's Fiction",
 'Biography & Autobiography': "Nonfiction",
 'History': "Nonfiction",
 'Literary Criticism': "Nonfiction",
 'Philosophy': "Nonfiction",
 'Religion': "Nonfiction",
 'Comics & Graphic Novels': "Fiction",
 'Drama': "Fiction",
 'Juvenile Nonfiction': "Children's Nonfiction",
 'Science': "Nonfiction",
 'Poetry': "Fiction"}

books["simple_categories"] = books["categories"].map(category_mapping)

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5590  9788172235222  8172235224
# 5591  9788173031014  8173031010
# 5592  9788179921623  817992162X
# 5593  9788185300535  8185300534
# 5594  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5590                                  Mistaken Identity
# 5591                                Journey to the East
# 5592  The Monk Who Sold His Ferrari: A Fable About F...
# 5593                                          I Am that
# 5594                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5590                              Nayantara Sahgal
# 5591                                 Hermann Hesse
# 5592                                  Robin Sharma
# 5593  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5594                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5590        Indic fiction (English)
# 5591              Adventure stories
# 5592               Health & Fitness
# 5593                     Philosophy
# 5594                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5590  http://books.google.com/books/content?id=q-tKP...
# 5591  http://books.google.com/books/content?id=rq6JP...
# 5592  http://books.google.com/books/content?id=c_7mf...
# 5593  http://books.google.com/books/content?id=Fv_JP...
# 5594  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5590  On A Train Journey Home To North India After L...          2003.0
# 5591  This book tells the tale of a man who goes on ...          2002.0
# 5592  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5593  This collection of the timeless teachings of o...          1999.0
# 5594  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5590            2.93      324.0            0.0
# 5591            3.70      175.0           24.0
# 5592            3.82      198.0         1568.0
# 5593            4.51      531.0          104.0
# 5594            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                Spider's Web : A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5590                                  Mistaken Identity
# 5591                                Journey to the East
# 5592  The Monk Who Sold His Ferrari: A Fable About F...
# 5593    I Am that : Talks with Sri Nisargadatta Maharaj
# 5594                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...               NaN
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...               NaN
# 4     9780006280934 "In The Problem of Pain, C.S. Le...               NaN
# ...                                                 ...               ...
# 5590  9788172235222 On A Train Journey Home To North...               NaN
# 5591  9788173031014 This book tells the tale of a ma...               NaN
# 5592  9788179921623 Wisdom to Create a Life of Passi...               NaN
# 5593  9788185300535 This collection of the timeless ...        Nonfiction
# 5594  9789027712059 Since the three volume edition o...        Nonfiction
#
# [5595 rows x 14 columns]

# %%
books[~(books["simple_categories"].isna())]
# Out:
#              isbn13      isbn10                     title  \
# 0     9780002005883  0002005883                    Gilead
# 2     9780006178736  0006178731            Rage of angels
# 8     9780006482079  0006482074       Warhost of Vastmark
# 30    9780006646006  000664600X        Ocean Star Express
# 47    9780007121014  0007121016        Taken at the Flood
# ...             ...         ...                       ...
# 5580  9783791329284  3791329286            Joseph Cornell
# 5586  9784770028969  4770028962        Coin Locker Babies
# 5587  9788122200850  8122200850          Cry, the Peacock
# 5593  9788185300535  8185300534                 I Am that
# 5594  9789027712059  9027712050  The Berlin Phenomenology
#
#                                            authors           categories  \
# 0                               Marilynne Robinson              Fiction
# 2                                   Sidney Sheldon              Fiction
# 8                                      Janny Wurts              Fiction
# 30                        Mark Haddon;Peter Sutton     Juvenile Fiction
# 47                                 Agatha Christie              Fiction
# ...                                            ...                  ...
# 5580              Joseph Cornell;Alison Baverstock  Juvenile Nonfiction
# 5586                                           村上龍              Fiction
# 5587                                   Anita Desai              Fiction
# 5593  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit           Philosophy
# 5594                 Georg Wilhelm Friedrich Hegel              History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 8     http://books.google.com/books/content?id=uOL0f...
# 30    http://books.google.com/books/content?id=I2QZA...
# 47    http://books.google.com/books/content?id=3gWlx...
# ...                                                 ...
# 5580  http://books.google.com/books/content?id=KnO8A...
# 5586  http://books.google.com/books/content?id=87DJw...
# 5587  http://books.google.com/books/content?id=_QKwV...
# 5593  http://books.google.com/books/content?id=Fv_JP...
# 5594  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 8     Tricked once more by his wily half-brother, Ly...          1995.0
# 30    Joe and his parents are enjoying a summer holi...          2002.0
# 47    A Few Weeks After Marrying An Attractive Young...          2002.0
# ...                                                 ...             ...
# 5580  Provides an introduction to the American artis...          2003.0
# 5586  Rescued from the lockers in which they were le...          2002.0
# 5587  This book is the story of a young girl obsesse...          1980.0
# 5593  This collection of the timeless teachings of o...          1999.0
# 5594  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 2               3.93      512.0        29532.0
# 8               4.03      522.0         2966.0
# 30              3.50       32.0            1.0
# 47              3.71      352.0         8852.0
# ...              ...        ...            ...
# 5580            4.06       27.0           31.0
# 5586            3.75      393.0         5560.0
# 5587            3.22      218.0          134.0
# 5593            4.51      531.0          104.0
# 5594            0.00      210.0            0.0
#
#                                    title_and_subtitle  \
# 0                                              Gilead
# 2                                      Rage of angels
# 8                                 Warhost of Vastmark
# 30                                 Ocean Star Express
# 47                                 Taken at the Flood
# ...                                               ...
# 5580                Joseph Cornell : Secrets in a Box
# 5586                               Coin Locker Babies
# 5587                                 Cry, the Peacock
# 5593  I Am that : Talks with Sri Nisargadatta Maharaj
# 5594                         The Berlin Phenomenology
#
#                                      tagged_description      simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...                Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...                Fiction
# 8     9780006482079 Tricked once more by his wily ha...                Fiction
# 30    9780006646006 Joe and his parents are enjoying...     Children's Fiction
# 47    9780007121014 A Few Weeks After Marrying An At...                Fiction
# ...                                                 ...                    ...
# 5580  9783791329284 Provides an introduction to the ...  Children's Nonfiction
# 5586  9784770028969 Rescued from the lockers in whic...                Fiction
# 5587  9788122200850 This book is the story of a youn...                Fiction
# 5593  9788185300535 This collection of the timeless ...             Nonfiction
# 5594  9789027712059 Since the three volume edition o...             Nonfiction
#
# [4048 rows x 14 columns]

# %%
from transformers import pipeline

fiction_categories = ["Fiction", "Nonfiction"]

pipe = pipeline("zero-shot-classification",
                model="facebook/bart-large-mnli", device ='cuda:0')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[0]

# %%
pipe(sequence, fiction_categories)
# Out:
# {'sequence': 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.',
#  'labels': ['Fiction', 'Nonfiction'],
#  'scores': [0.8438267111778259, 0.15617327392101288]}

# %%
import numpy as np

max_index = np.argmax(pipe(sequence, fiction_categories)["scores"])
max_label = pipe(sequence, fiction_categories)["labels"][max_index]
max_label
# Out:
# 'Fiction'

# %%
def generate_predictions(sequence, categories):
    predictions = pipe(sequence, categories)
    max_index = np.argmax(predictions["scores"])
    max_label = predictions["labels"][max_index]
    return max_label

# %%
from tqdm import tqdm

actual_cats = []
predicted_cats = []

for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Fiction"]
# Out:
#   2%|▏         | 6/300 [00:00<00:36,  8.09it/s]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 100%|██████████| 300/300 [00:22<00:00, 13.06it/s]

# %%
for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Nonfiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Nonfiction"]
# Out:
# 100%|██████████| 300/300 [00:24<00:00, 12.32it/s]

# %%
predictions_df = pd.DataFrame({"actual_categories": actual_cats, "predicted_categories": predicted_cats})

# %%
predictions_df
# Out:
#     actual_categories predicted_categories
# 0             Fiction              Fiction
# 1             Fiction              Fiction
# 2             Fiction              Fiction
# 3             Fiction           Nonfiction
# 4             Fiction              Fiction
# ..                ...                  ...
# 595        Nonfiction           Nonfiction
# 596        Nonfiction           Nonfiction
# 597        Nonfiction           Nonfiction
# 598        Nonfiction           Nonfiction
# 599        Nonfiction           Nonfiction
#
# [600 rows x 2 columns]

# %%
predictions_df["correct_prediction"] = (
    np.where(predictions_df["actual_categories"] == predictions_df["predicted_categories"], 1, 0)
)

# %%
predictions_df["correct_prediction"].sum() / len(predictions_df)
# Out:
# np.float64(0.7816666666666666)

# %%
isbns = []
predicted_cats = []

missing_cats = books.loc[books["simple_categories"].isna(), ["isbn13", "description"]].reset_index(drop=True)

# %%
for i in tqdm(range(0, len(missing_cats))):
    sequence = missing_cats["description"][i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    isbns += [missing_cats["isbn13"][i]]
# Out:
# 100%|██████████| 1547/1547 [01:58<00:00, 13.01it/s]

# %%
missing_predictions_df =  pd.DataFrame({"isbn13": isbns, "predicted_categories": predicted_cats})

# %%
missing_predictions_df
# Out:
#              isbn13 predicted_categories
# 0     9780002261982              Fiction
# 1     9780006280897           Nonfiction
# 2     9780006280934           Nonfiction
# 3     9780006380832           Nonfiction
# 4     9780006470229              Fiction
# ...             ...                  ...
# 1542  9788125026600           Nonfiction
# 1543  9788171565641              Fiction
# 1544  9788172235222              Fiction
# 1545  9788173031014           Nonfiction
# 1546  9788179921623              Fiction
#
# [1547 rows x 2 columns]

# %%
books = pd.merge(books, missing_predictions_df, on="isbn13", how="left")
books["simple_categories"] =  np.where(books["simple_categories"].isna(), books["predicted_categories"], books["simple_categories"])
books = books.drop(columns=["predicted_categories"])

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5590  9788172235222  8172235224
# 5591  9788173031014  8173031010
# 5592  9788179921623  817992162X
# 5593  9788185300535  8185300534
# 5594  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5590                                  Mistaken Identity
# 5591                                Journey to the East
# 5592  The Monk Who Sold His Ferrari: A Fable About F...
# 5593                                          I Am that
# 5594                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5590                              Nayantara Sahgal
# 5591                                 Hermann Hesse
# 5592                                  Robin Sharma
# 5593  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5594                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5590        Indic fiction (English)
# 5591              Adventure stories
# 5592               Health & Fitness
# 5593                     Philosophy
# 5594                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5590  http://books.google.com/books/content?id=q-tKP...
# 5591  http://books.google.com/books/content?id=rq6JP...
# 5592  http://books.google.com/books/content?id=c_7mf...
# 5593  http://books.google.com/books/content?id=Fv_JP...
# 5594  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5590  On A Train Journey Home To North India After L...          2003.0
# 5591  This book tells the tale of a man who goes on ...          2002.0
# 5592  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5593  This collection of the timeless teachings of o...          1999.0
# 5594  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5590            2.93      324.0            0.0
# 5591            3.70      175.0           24.0
# 5592            3.82      198.0         1568.0
# 5593            4.51      531.0          104.0
# 5594            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                Spider's Web : A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5590                                  Mistaken Identity
# 5591                                Journey to the East
# 5592  The Monk Who Sold His Ferrari: A Fable About F...
# 5593    I Am that : Talks with Sri Nisargadatta Maharaj
# 5594                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5590  9788172235222 On A Train Journey Home To North...           Fiction
# 5591  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5592  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5593  9788185300535 This collection of the timeless ...        Nonfiction
# 5594  9789027712059 Since the three volume edition o...        Nonfiction
#
# [5595 rows x 14 columns]

# %%
books.to_csv("books_with_categories", index=False )

# %%
from google.colab import files
files.download("books_with_categories")
